# %%
#!/usr/bin/env python
# coding: utf-8

# Leire Larizgoitia Arcocha

from __future__ import division

import matplotlib
matplotlib.rcParams['text.usetex'] = True
from matplotlib import pyplot as plt
#plt.rcParams.update({'font.size': 20})
import matplotlib.colors as mcolors
import matplotlib.ticker as mtick
from matplotlib.ticker import MultipleLocator
import numpy as np
import math
import numpy.ma as ma

from scipy.optimize import curve_fit
from scipy import interpolate
from scipy.integrate import trapz, simps, quad

from scipy.signal import find_peaks

from scipy.stats import poisson
from scipy.special import factorial
from scipy import stats


import os
import glob

# %%
R7378A_NO = ['BA1630','BA1623','BA1629','BA1624','BA1634','BA1635','BA1633']


delta_t = 25 #samples

R1073_1PEfit = np.loadtxt('GaP_LEDcalibration/calibrun_1073-1098_parameters_1PEfit.txt', skiprows=0, dtype='float')
R1073_2PEfit = np.loadtxt('GaP_LEDcalibration/calibrun_1073-1098_parameters_2PEfit.txt', skiprows=0, dtype='float')

R701_1PEfit = np.loadtxt('GaP_LEDcalibration/calibrun_701-732_parameters_1PEfit.txt', skiprows=0, dtype='float')
R701_2PEfit = np.loadtxt('GaP_LEDcalibration/calibrun_701-732_parameters_2PEfit.txt', skiprows=0, dtype='float')

R620_1PEfit = np.loadtxt('GaP_LEDcalibration/calibrun_620-628_parameters_1PEfit.txt', skiprows=0, dtype='float')
R620_2PEfit = np.loadtxt('GaP_LEDcalibration/calibrun_620-628_parameters_2PEfit.txt', skiprows=0, dtype='float')

R235_1PEfit = np.loadtxt('GaP_LEDcalibration/calibrun_235-245_parameters_1PEfit.txt', skiprows=0, dtype='float')
R235_2PEfit = np.loadtxt('GaP_LEDcalibration/calibrun_235-245_parameters_2PEfit.txt', skiprows=0, dtype='float')

R22_1PEfit = np.loadtxt('GaP_LEDcalibration/calibrun_22-30_parameters_1PEfit.txt', skiprows=0, dtype='float')
R22_2PEfit = np.loadtxt('GaP_LEDcalibration/calibrun_22-30_parameters_2PEfit.txt', skiprows=0, dtype='float')


fig, ax1 = plt.subplots()


ax1.errorbar(R7378A_NO, R1073_1PEfit[:,8], yerr=R1073_1PEfit[:,9], fmt="o", label='Run 1073-1098 | 1 Jul 2024')

ax1.errorbar(R7378A_NO, R701_1PEfit[:,8], yerr=R701_1PEfit[:,9],  fmt="o", label='Run 701-732 | 7 Jun 2024')

ax1.errorbar(R7378A_NO, R620_1PEfit[:,8], yerr=R620_1PEfit[:,9],  fmt="o", label='Run 620-628 | 17 May 2024')

ax1.errorbar(R7378A_NO, R235_1PEfit[:,8], yerr=R235_1PEfit[:,9], fmt="o", label='Run 235-245 | 27 Mar 2024')

ax1.errorbar(R7378A_NO, R22_1PEfit[:,8], yerr=R22_1PEfit[:,9], color = 'black', fmt="o", label='Run 22-30 | 16 Feb 2024')

ax1.set_xlabel('PMT serial number')
ax1.set_ylabel('charge for 1PE')
ax1.legend()
ax2 = ax1.twiny()  # instantiate a second axes that shares the same x-axis

ax2.set_xlabel('PMT ID')
ax2.set_xlim(0, 6)

ax1.legend(loc='upper center') #, bbox_to_anchor=(1, 0.5))

plt.title(f'Window {delta_t} samples: ({delta_t*8} ns) | Fit 0PE, 1PE')
#plt.savefig('GaP_LEDcalibration/PMTCalibrationCompare_1PEfit.png')

plt.show()


fig, ax1 = plt.subplots()


ax1.errorbar(R7378A_NO, R1073_2PEfit[:,8], yerr=R1073_2PEfit[:,9], fmt="o", label='Run 1073-1098 | 1 Jul 2024')

ax1.errorbar(R7378A_NO, R701_2PEfit[:,8], yerr=R701_2PEfit[:,9],  fmt="o", label='Run 701-732 | 7 Jun 2024')

ax1.errorbar(R7378A_NO, R620_2PEfit[:,8], yerr=R620_2PEfit[:,9],  fmt="o", label='Run 620-628 | 17 May 2024')

ax1.errorbar(R7378A_NO, R235_2PEfit[:,8], yerr=R235_2PEfit[:,9], fmt="o", label='Run 235-245 | 27 Mar 2024')

ax1.errorbar(R7378A_NO, R22_2PEfit[:,8], yerr=R22_2PEfit[:,9], color = 'black', fmt="o", label='Run 22-30 | 16 Feb 2024')

ax1.set_xlabel('PMT serial number')
ax1.set_ylabel('charge for 1PE')
ax1.legend()
ax2 = ax1.twiny()  # instantiate a second axes that shares the same x-axis

ax2.set_xlabel('PMT ID')
ax2.set_xlim(0, 6)

ax1.legend(loc='upper center') #, bbox_to_anchor=(1, 0.5))

plt.title(f'Window {delta_t} samples: ({delta_t*8} ns) | Fit 0PE, 1PE, 2PE')
#plt.savefig('GaP_LEDcalibration/PMTCalibration_runsCompare_new.png')

plt.show()
